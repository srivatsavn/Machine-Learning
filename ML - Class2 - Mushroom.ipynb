# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
mush = pd.read_csv('C:/Users/Administrator/Desktop/Datasets/mushroom.csv')

# %%
mush.head()
# Out:
#   class cap_shape cap-surface cap-color bruises? odor gill-attachment  \
# 0     p         x           s         n        t    p               f
# 1     e         x           s         y        t    a               f
# 2     e         b           s         w        t    l               f
# 3     p         x           y         w        t    p               f
# 4     e         x           s         g        f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
mush_new = mush.drop('class', axis =1)

# %%
mush_dummies = pd.get_dummies(mush_new)

# %%
mush_dummies['class'] = mush['class']

# %%
mush_dummies.shape
# Out:
# (8124, 118)

# %%
train, test = train_test_split(mush_dummies, test_size = 0.3, random_state = 100)

# %%
train_y = train['class']
test_y = test['class']
train_x = train.drop('class', axis = 1)
test_x = test.drop('class', axis = 1)

model = DecisionTreeClassifier(random_state=100, max_depth=3)
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
test_pred = model.predict(test_x)
print(len(test_pred))
test_pred[:5]
# Out:
# 2438
# array(['e', 'p', 'e', 'p', 'e'], dtype=object)

# %%
df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted': test_pred})
df_pred.head()
# Out:
#      actual predicted
# 2690      e         e
# 5021      p         p
# 2708      e         e
# 1405      p         p
# 2935      e         e

# %%
df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']
df_pred.head()
# Out:
#      actual predicted  pred_status
# 2690      e         e         True
# 5021      p         p         True
# 2708      e         e         True
# 1405      p         p         True
# 2935      e         e         True

# %%
df_pred['pred_status'].value_counts()
# Out:
# True     2401
# False      37
# Name: pred_status, dtype: int64

# %%
df_pred['pred_status'].value_counts() / df_pred.shape[0] * 100
# Out:
# True     98.482363
# False     1.517637
# Name: pred_status, dtype: float64

# %% [markdown]
# # RANDOM FOREST

# %%
all_cols = train.drop('class', axis=1).columns
cols_used = all_cols[np.random.randint(1, len(all_cols), 3)]
print(cols_used)

train_y = train['class']
test_y = test['class']

train_x = train[cols_used]
test_x = test[cols_used]

model = DecisionTreeClassifier(random_state=100)
model.fit(train_x,train_y)
pd.DataFrame(model.predict(test_x), index=test.index, columns=['Attrition_Predicted'])
# Out:
# Index(['stalk-surface-below-ring_s', 'stalk-color-below-ring_w',
#        'cap-color_g'],
#       dtype='object')
#      Attrition_Predicted
# 2690                   e
# 5021                   e
# 2708                   e
# 1405                   e
# 2935                   e
# 3438                   e
# 4140                   p
# 1885                   e
# 2740                   e
# 4084                   p
# 4186                   e
# 5321                   e
# 6994                   e
# 7928                   e
# 3604                   p
# 7764                   e
# 2582                   e
# 1514                   e
# 3638                   e
# 874                    e
# 7840                   e
# 4982                   p
# 7461                   e
# 7861                   e
# 1639                   e
# 3852                   e
# 2413                   e
# 3978                   e
# 6755                   e
# 1013                   e
# ...                  ...
# 6216                   e
# 4845                   e
# 5111                   p
# 1311                   e
# 107                    e
# 2077                   e
# 5764                   e
# 1206                   e
# 4876                   e
# 8099                   e
# 7828                   e
# 5623                   e
# 1789                   e
# 1                      e
# 4885                   p
# 6382                   p
# 3636                   e
# 3618                   e
# 3103                   p
# 945                    e
# 3169                   e
# 6679                   p
# 1961                   e
# 3013                   e
# 7767                   e
# 1895                   e
# 3096                   e
# 2533                   p
# 5277                   p
# 4121                   e
#
# [2438 rows x 1 columns]

# %%
train_y = train['class']
test_y = test['class']

train_x = train.drop('class', axis = 1)
test_x = test.drop('class', axis = 1)

from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(random_state=100)
model_rf.fit(train_x, train_y)

test_pred = model_rf.predict(test_x)
df_pred = pd.DataFrame({'actual' : test_y,
                       'predicted' : test_pred})
df_pred['pred_status'] = df_pred['actual'] == df_pred['predicted']
df_pred['pred_status'].sum() / df_pred.shape[0] * 100
# Out:
# 100.0
