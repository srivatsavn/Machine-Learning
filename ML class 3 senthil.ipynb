# %%
import numpy as np

# %%
data = np.array([[1,2],[6,7],[1,3],[2,1],[8,6],[7,9]])
k=2

#seed = np.random.randint(1,6,2)
#c1=data[seed[0]].reshape(1,-1)
#c2=data[seed[1]].reshape(1,-1)
#clust=np.concatenate((c1,c2))

c1 = np.array([1,2]).reshape(1,-1)
c2 = np.array([1,3]).reshape(1,-1)
clust=np.concatenate((c1,c2))

dist=np.zeros([6,2])
n=0
while(n<10):
    for i in range(k):
        for j in range(len(data)):
            dist[j,i]=np.sqrt(sum((clust[i,:]-data[j,:])**2))
            
    mi=np.argmin(dist,axis=1)  
    
    clust1=data[mi==0]   
    clust2=data[mi==1] 
    
    c1_upd=np.mean(clust1,axis=0) 
    c1_upd=c1_upd.reshape(1,-1)
    
    c2_upd=np.mean(clust2,axis=0) 
    c2_upd=c2_upd.reshape(1,-1)
    
    print(c1_upd)
    print(c2_upd)
    
    d1=np.sum((np.abs(c1-c1_upd)))
    d2=np.sum((np.abs(c2-c2_upd)))

    if (d1==0 and d2==0):
        break
    c1=c1_upd
    c2=c2_upd
    clust=np.concatenate((c1_upd,c2_upd))
    n=n+1
print("The cluster1:") 
print(clust1)  
print("The cluster2:") 
print(clust2)
# Out:
# [[1.5 1.5]]
# [[5.5  6.25]]
# [[1.33333333 2.        ]]
# [[7.         7.33333333]]
# [[1.33333333 2.        ]]
# [[7.         7.33333333]]
# The cluster1:
# [[1 2]
#  [1 3]
#  [2 1]]
# The cluster2:
# [[6 7]
#  [8 6]
#  [7 9]]

# %%
import pandas as pd

df = pd.DataFrame({
        'x': [12,20,28,18,29,33,24,45,45,52,51,52,55,53,55,61,64,69,72],
        'y': [39,36,30,52,54,46,55,59,63,70,66,63,58,23,14,8,19,7,24]
})

from sklearn.cluster import KMeans
kmean_mod = KMeans(n_clusters=3)
kmean_mod.fit(df)
labels=kmean_mod.predict(df)

df['label'] = labels

centroids = kmean_mod.cluster_centers_

from matplotlib import pyplot as plt

colmap = {1: 'r', 2: 'g', 3: 'b'}
fig=plt.figure(figsize=(10,8))

plt.scatter(df['x'], df['y'], c=labels, s=50);
plt.scatter(centroids[:,0], centroids[:,1], marker = '*', c='g' , s=100)

df
# Out:
#      x   y  label
# 0   12  39      2
# 1   20  36      2
# 2   28  30      2
# 3   18  52      2
# 4   29  54      2
# 5   33  46      2
# 6   24  55      2
# 7   45  59      0
# 8   45  63      0
# 9   52  70      0
# 10  51  66      0
# 11  52  63      0
# 12  55  58      0
# 13  53  23      1
# 14  55  14      1
# 15  61   8      1
# 16  64  19      1
# 17  69   7      1
# 18  72  24      1

# %%
vote = pd.read_csv('C:/Users/Administrator/Desktop/Datasets/voting.csv', index_col=0)

# %%
vote
# Out:
#                       Armenia  Australia  Austria  Azerbaijan  Belgium  \
# From country
# Albania                   2.0       12.0      0.0         0.0      0.0
# Armenia                   NaN        0.0      4.0         0.0      0.0
# Australia                 0.0        NaN      3.0         0.0     12.0
# Austria                   0.0        3.0      NaN         0.0      0.0
# Azerbaijan                0.0        2.0      0.0         NaN      0.0
# Belarus                   7.0        1.0      0.0         8.0      0.0
# Belgium                   7.0        4.0      3.0         0.0      NaN
# Bosnia & Herzegovina      0.0        3.0      5.0         8.0      0.0
# Bulgaria                  8.0        5.0      4.0         1.0      0.0
# Croatia                   0.0        5.0      6.0         0.0      0.0
# Cyprus                    8.0        5.0      0.0         0.0      0.0
# Czech Republic            8.0        1.0      4.0         6.0      0.0
# ...

# %%
vote.isnull().sum()
# Out:
# Armenia            1
# Australia          1
# Austria            1
# Azerbaijan         1
# Belgium            1
# Bulgaria           1
# Croatia            1
# Cyprus             1
# Czech Republic     1
# France             1
# Georgia            1
# Germany            1
# Hungary            1
# Israel             1
# Italy              1
# Latvia             1
# Lithuania          1
# Malta              1
# Poland             1
# Russia             1
# Serbia             1
# Spain              1
# Sweden             1
# The Netherlands    1
# Ukraine            1
# United Kingdom     1
# dtype: int64

# %%
vote.max()
# Out:
# Armenia            12.0
# Australia          12.0
# Austria            10.0
# Azerbaijan         10.0
# Belgium            12.0
# Bulgaria           12.0
# Croatia            10.0
# Cyprus             12.0
# Czech Republic      0.0
# France             12.0
# Georgia             8.0
# Germany             8.0
# Hungary            10.0
# Israel              6.0
# Italy              10.0
# Latvia             12.0
# Lithuania          12.0
# Malta               6.0
# Poland             12.0
# Russia             12.0
# Serbia             12.0
# Spain               4.0
# Sweden             12.0
# The Netherlands    10.0
# Ukraine            12.0
# United Kingdom      4.0
# dtype: float64

# %%
vote.fillna(12, inplace=True)

# %%
vote.isnull().sum()
# Out:
# Armenia            0
# Australia          0
# Austria            0
# Azerbaijan         0
# Belgium            0
# Bulgaria           0
# Croatia            0
# Cyprus             0
# Czech Republic     0
# France             0
# Georgia            0
# Germany            0
# Hungary            0
# Israel             0
# Italy              0
# Latvia             0
# Lithuania          0
# Malta              0
# Poland             0
# Russia             0
# Serbia             0
# Spain              0
# Sweden             0
# The Netherlands    0
# Ukraine            0
# United Kingdom     0
# dtype: int64

# %%
kmean_mod = KMeans(n_clusters=3)
kmean_mod.fit(vote)
labels=kmean_mod.predict(vote)
labels

centroids = kmean_mod.cluster_centers_
centroids.shape
# Out:
# (3, 26)

# %%
cc = pd.read_csv('C:/Users/Administrator/Desktop/Datasets/CC_DATA.csv')

# %%
cc
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# 5     C10006  1809.828751           1.000000    1333.28              0.00
# 6     C10007   627.260806           1.000000    7091.01           6402.63
# 7     C10008  1823.652743           1.000000     436.20              0.00
# 8     C10009  1014.926473           1.000000     861.49            661.49
# 9     C10010   152.225975           0.545455    1281.60           1281.60
# 10    C10011  1293.124939           1.000000     920.12              0.00
# 11    C10012   630.794744           0.818182    1492.18           1492.18
# ...

# %%
cc.drop(['CUST_ID'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import normalize
cc = cc.dropna()

# %%
cc.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
cc=normalize(cc)

# %%
kmean_mod = KMeans(n_clusters=5, random_state=0)
fit_model = kmean_mod.fit(cc)
labels=kmean_mod.predict(cc)
labels

centroids = kmean_mod.cluster_centers_
centroids.shape
# Out:
# (5, 17)

# %%
from sklearn.decomposition import PCA
pca= PCA(2)
pcafit = pca.fit(cc)
pcadata = pcafit.fit_transform(cc)

# %%
pcadata
# Out:
# array([[-0.3171941 , -0.07028001],
#        [ 0.3208376 , -0.13731636],
#        [-0.20189186, -0.20310878],
#        ...,
#        [-0.38785235, -0.09029089],
#        [-0.32337848, -0.20481106],
#        [-0.11672954,  0.29878135]])

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,8))
plt.scatter(pcadata[:,0], pcadata[:,1], c=labels )

# %%
from scipy import ndimage
from sklearn import cluster

# %%
img = ndimage.imread('flag.png')
plt.figure()
plt.imshow(img)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
x,y,z = img.shape

# %%
img1 = img.reshape(x*y,z)

# %%
img1
# Out:
# array([[255, 153,  51],
#        [255, 153,  51],
#        [255, 153,  51],
#        ...,
#        [ 18, 136,   7],
#        [ 18, 136,   7],
#        [ 18, 136,   7]], dtype=uint8)

# %%
kmean_mod = KMeans(n_clusters=3)
kmean_mod.fit(img1)
centroids = kmean_mod.cluster_centers_
centroids = centroids.astype(int)
lab = kmean_mod.labels_
plt.figure()
plt.imshow(centroids[lab].reshape(x,y,z))

# %%
img = ndimage.imread('TNR.jpg')
plt.figure()
plt.imshow(img)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
x,y,z = img.shape
img1 = img.reshape(x*y,z)

# %%
img1
# Out:
# array([[99, 97, 84],
#        [88, 86, 73],
#        [77, 78, 64],
#        ...,
#        [61, 79, 63],
#        [66, 83, 67],
#        [56, 73, 57]], dtype=uint8)

# %%
kmean_mod = KMeans(n_clusters=2)
kmean_mod.fit(img1)
centroids = kmean_mod.cluster_centers_
centroids = centroids.astype(int)
lab = kmean_mod.labels_
plt.figure()
plt.imshow(centroids[lab].reshape(x,y,z))
